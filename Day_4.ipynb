# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakp972/machine_learning_4/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('/content/drive/MyDrive/Machine_learning_15 01 2024/Dataset_03.csv')
df
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience  Purchased
# 0           0       0      1    0   39343              1.1          0
# 1           0       1      0    0   46205              1.3          1
# 2           0       1      0    0   37731              1.5          0
# 3           0       1      0    0   43525              2.0          0
# 4           0       0      0    1   39891              2.2          0
# 5           0       0      1    0   56642              2.9          0
# 6           0       1      0    0   60150              3.0          1
# 7           1       0      0    0   54445              3.2          0
# 8           0       0      1    0   64445              3.2          1
# 9           0       0      1    0   57189              3.7          0
# 10          0       0      1    0   63218              3.9          1
# 11          0       0      0    1   55794              4.0          0
# ...

# %% [markdown]
# #Feature Scaling
# dataset jab ye model ko diya jaiga tab vaalues ek scale per mil jana chaiye so that
# 1. simple feture scaling  Xnew=xold/Xmax
# 2. standarization Xstand=(x-mean(x)/standard deviation(x)).values between -3 to 3
# 3. normalization(min-max)Xnew=(X-Xmin)/(Xmax-Xmin). values will be between 0 to 1  mean = sum of all values / Number of values

# %%
x=df.iloc[:,:-1]
x.shape
# Out:
# (30, 6)

# %%
y=df.iloc[:,-1]
y.shape# second value is 1
# Out:
# (30,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
x_train.shape
# Out:
# (24, 6)

# %%
sc=StandardScaler()
x_train.iloc[:,4:]=sc.fit_transform(x_train.iloc[:,4:])

# %%
x_train

# %%
x_test.iloc[:,4:] = sc.transform(x_test.iloc[:,4:] )

# %%
x_test
# Out:
#     Australia  Canada  Dubai  USA    Salary  YearsExperience
# 17          0       1      0    0  0.294676         0.019056
# 21          1       0      0    0  0.817543         0.607066
# 10          0       0      1    0 -0.389511        -0.438286
# 19          0       1      0    0  0.668344         0.247727
# 14          1       0      0    0 -0.462061        -0.242282
# 20          0       1      0    0  0.592523         0.509065
